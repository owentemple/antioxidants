# %%
import pandas as pd

# %%
df = pd.read_csv("antioxidants-plus-url.csv", encoding="utf")

# %%
df.head()
# Out:
#    Unnamed: 0  Id  Category               Category name  \
# 0           0   1         1  Berries and berry products
# 1           1   2         1  Berries and berry products
# 2           2   3         1  Berries and berry products
# 3           3   4         1  Berries and berry products
# 4           4   5         1  Berries and berry products
#
#                                        Product  \
# 0                          Amla berries, dried
# 1     Amla, Indian Gooseberries, whole, canned
# 2  Amla, syrup from canned Indian Gooseberries
# 3                             Bilberries, wild
# 4                             Bilberries, wild
#
#   Manufacturer / product label / country of origin Procured in  \
# 0                                            India       India
# 1                   Roopaks, Ajmal Khan, N.\nDehli       India
# 2                   Roopaks, Ajmal Khan, N.\nDehli       India
# 3                                           Norway      Norway
# ...

# %%
df.iloc[0:100]
# Out:
#     Unnamed: 0   Id  Category               Category name  \
# 0            0    1         1  Berries and berry products
# 1            1    2         1  Berries and berry products
# 2            2    3         1  Berries and berry products
# 3            3    4         1  Berries and berry products
# 4            4    5         1  Berries and berry products
# 5            5    6         1  Berries and berry products
# 6            6    7         1  Berries and berry products
# 7            7    8         1  Berries and berry products
# 8            8    9         1  Berries and berry products
# 9            9   10         1  Berries and berry products
# 10          10   11         1  Berries and berry products
# 11          11   12         1  Berries and berry products
# 12          12   13         1  Berries and berry products
# 13          13   14         1  Berries and berry products
# 14          14   15         1  Berries and berry products
# ...

# %%
df['Query'] = df['Product'].str.replace("\s|,|\(|\)+", "+")

# %%
df['Amazon_url'] = "https://www.amazon.com/s/ref=nb_sb_noss?url=search-alias%3Daps&field-keywords=" + df['Query']

# %%
df.to_csv("antioxidants-plus-url.csv")
